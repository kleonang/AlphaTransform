# %%
# %load_ext autoreload
# %autoreload 2

import pickle
from backtester.StrategySimulator import StrategySimulator

# %%
# Set simulation start and end dates
sim_start = '2011-01-01'
sim_end = '2017-12-07'
# Set in-sample and out-of-sample start dates
is_start = '2013-04-10'
os_start = '2017-01-03'
simulator = StrategySimulator(sim_start, sim_end, is_start, os_start)

# %%
simulator.simulate()
# Out:
#                 AABA      AAON      AAPL      AAWW      AAXJ      AAXN  \
# Date
# 2011-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2017-12-01  0.007730 -0.005867 -0.001921 -0.048634  0.077964 -0.143131
# 2017-12-04  0.012620 -0.112566  0.002865  0.496426 -0.033899 -0.098658
# 2017-12-05 -0.001966  0.230384  0.003846  0.466828  0.077721 -0.129230
# 2017-12-06 -0.003889  0.377639  0.003854 -0.062967  0.032357 -0.128865
# 2017-12-07  0.004843  0.022291 -0.000004 -0.229854  0.044035 -0.158798
#
#                 ABAX      ABCB  ABCO      ABMD  ...      YNDX      YORW  \
# Date                                            ...
# 2011-01-03       NaN       NaN   NaN       NaN  ...       NaN       NaN
# 2011-01-04       NaN       NaN   NaN       NaN  ...       NaN       NaN
# 2011-01-05       NaN       NaN   NaN       NaN  ...       NaN       NaN
# 2011-01-06       NaN       NaN   NaN       NaN  ...       NaN       NaN
# 2011-01-07       NaN       NaN   NaN       NaN  ...       NaN       NaN
# ...              ...       ...   ...       ...  ...       ...       ...
# 2017-12-01  0.308863  0.080885   NaN -0.059803  ... -0.021744  2.230151
# 2017-12-04  0.438503  0.155321   NaN  0.040202  ...  0.004720  0.700646
# 2017-12-05 -0.094963 -0.201300   NaN -0.001444  ... -0.026234  0.233630
# 2017-12-06  0.084524 -0.261534   NaN -0.073044  ... -0.037800  0.386656
# 2017-12-07  0.050358 -0.344578   NaN -0.049904  ... -0.047878 -0.247078
#
#                 YRCW        YY      ZBRA      ZEUS      ZGNX      ZION  \
# Date
# 2011-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2017-12-01 -0.143510 -0.158139 -0.153632 -0.159583 -0.004996  0.009104
# 2017-12-04 -0.059565 -0.122211 -0.103174  1.134828 -0.007712  0.031140
# 2017-12-05 -0.062730 -0.085767 -0.153909  0.175364  0.388831  0.095592
# 2017-12-06 -0.022651 -0.111795 -0.083823  0.317779  0.007463 -0.013590
# 2017-12-07  0.051887 -0.086059  0.086114  0.276418  0.036769  0.067191
#
#                  ZIV      ZUMZ
# Date
# 2011-01-03       NaN       NaN
# 2011-01-04       NaN       NaN
# 2011-01-05       NaN       NaN
# 2011-01-06       NaN       NaN
# 2011-01-07       NaN       NaN
# ...              ...       ...
# 2017-12-01 -0.299434  0.605763
# 2017-12-04  0.320058  0.590619
# 2017-12-05  1.010401  0.232546
# 2017-12-06 -0.128524  0.202632
# 2017-12-07 -0.384259 -0.044589
#
# [1746 rows x 1048 columns]
# Max weight: 100100.0 %
#
# strat returns: Date
# 2013-04-10    2.775768
# 2013-04-11    0.361240
# 2013-04-12    0.191006
# 2013-04-15   -0.612735
# 2013-04-16   -0.171073
#                 ...
# 2017-12-01   -4.449223
# 2017-12-04    0.487116
# 2017-12-05    1.907810
# 2017-12-06    0.643692
# 2017-12-07    2.382709
# Name: strategy_returns, Length: 1177, dtype: float128
# In-Sample Sharpe Ratio: 2.303002316504233
# Out-of-Sample Sharpe Ratio: 2.3580584817942194
# OS/IS Ratio: 1.0239062570173865
#
# In-Sample IC: 0.014060450098585123
# Out-of-Sample IC: 0.003023124634761059
# In-Sample RIC: 0.01232206246942361
# Out-of-Sample RIC: 0.003367401771642645
# In-Sample CAGR: nan
# Out-of-Sample CAGR: nan
# In-Sample Max Drawdown: 44.88883034115277
# Out-of-Sample Max Drawdown: 34.5442666352146
# In-Sample Sortino Ratio: 2.6145751582461534
# Out-of-Sample Sortino Ratio: 5.754028896075911
# In-Sample Calmar Ratio: -1.417681315259088e+77
# Out-of-Sample Calmar Ratio: -1.2642757539454268e+34
# /Users/kleonang/Documents/NUS/Y4S1/CP4101/alphatransform/backtester/StrategyStatistics.py:39: RuntimeWarning: invalid value encountered in longdouble_scalars
#   return (self.returns_series + 1).prod() ** (252 / len(self.returns_series)) - 1

# %%
# TEST SIMULATION
simulator.simulate()
# Out:
# Max weight: 90.91 %
#
# strat returns: Date
# 2013-04-10    12.792086
# 2013-04-11     0.076574
# 2013-04-12    -1.464805
# 2013-04-15   -20.102353
# 2013-04-16    13.287322
#                 ...
# 2017-12-01    -0.087988
# 2017-12-04    -1.650567
# 2017-12-05    -4.854168
# 2017-12-06    -2.056793
# 2017-12-07     3.784296
# Name: strategy_returns, Length: 1177, dtype: float64
# In-Sample Sharpe Ratio: 1.4051449119627013
# Out-of-Sample Sharpe Ratio: 3.665007318262697
# OS/IS Ratio: 2.608277115805393
#
# In-Sample IC: 0.01945596671958278
# Out-of-Sample IC: 0.025207454359100084
# /Users/kleonang/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# In-Sample RIC: 0.02299383865878687
# Out-of-Sample RIC: 0.030895668390837336
# In-Sample CAGR: inf
# Out-of-Sample CAGR: 1.898524783400184e+110
# In-Sample Max Drawdown: 148.11961239324464
# Out-of-Sample Max Drawdown: 26.372015078320686
# In-Sample Sortino Ratio: 1.986494925155228
# Out-of-Sample Sortino Ratio: 5.430728920183106
# In-Sample Calmar Ratio: -inf
# Out-of-Sample Calmar Ratio: 7.169167837077451e+101

# %%
# 3-day Mean Reversion Strategy
simulator.simulate()
# Out:
# Max weight: 0.42 %
#
# strat returns: Date
# 2013-04-10    0.003453
# 2013-04-11    0.000935
# 2013-04-12   -0.000216
# 2013-04-15    0.000117
# 2013-04-16    0.010959
#                 ...
# 2017-12-01   -0.018033
# 2017-12-04   -0.016526
# 2017-12-05    0.002976
# 2017-12-06    0.005987
# 2017-12-07    0.002706
# Name: strategy_returns, Length: 1177, dtype: float64
# In-Sample Sharpe Ratio: 1.726751605528394
# Out-of-Sample Sharpe Ratio: 1.4704964695342444
# OS/IS Ratio: 0.8515969898775717
#
# In-Sample IC: 0.02329064720916611
# Out-of-Sample IC: 0.02553610033556031
# In-Sample RIC: 0.02500586678871656
# Out-of-Sample RIC: 0.02864128184196117
# In-Sample CAGR: 0.15324321021817733
# Out-of-Sample CAGR: 0.18869382392155498
# In-Sample Max Drawdown: 0.0669043797901281
# Out-of-Sample Max Drawdown: 0.057832789518049474
# In-Sample Sortino Ratio: 2.241791530187923
# Out-of-Sample Sortino Ratio: 1.9850239891042827
# In-Sample Calmar Ratio: 10.522283845111097
# Out-of-Sample Calmar Ratio: 3.038403066539335

# %%
# 1-day Mean Reversion Strategy
simulator.simulate()
# Out:
# Max weight: 0.42 %
#
# strat returns: Date
# 2013-04-10    0.004337
# 2013-04-11    0.001414
# 2013-04-12    0.000029
# 2013-04-15   -0.006603
# 2013-04-16    0.013443
#                 ...
# 2017-12-01    0.011891
# 2017-12-04   -0.003123
# 2017-12-05    0.007991
# 2017-12-06   -0.001566
# 2017-12-07   -0.001833
# Name: strategy_returns, Length: 1177, dtype: float64
# In-Sample Sharpe Ratio: 2.992985538530261
# Out-of-Sample Sharpe Ratio: 6.765497924830374
# OS/IS Ratio: 2.260451257693897
#
# In-Sample IC: 0.023621481411418215
# Out-of-Sample IC: 0.03274253112784197
# In-Sample RIC: 0.028520698828349345
# Out-of-Sample RIC: 0.03977695675645832
# In-Sample CAGR: 0.2768123523412849
# Out-of-Sample CAGR: 1.238815150045344
# In-Sample Max Drawdown: 0.06824234251056085
# Out-of-Sample Max Drawdown: 0.03570625088910051
# In-Sample Sortino Ratio: 3.978868449880611
# Out-of-Sample Sortino Ratio: 12.158686796007327
# In-Sample Calmar Ratio: 21.877141789075935
# Out-of-Sample Calmar Ratio: 31.566854797235898

# %%
# Example: (Close - Open) / (High - Low)
simulator.simulate()
# Out:
# Max weight: 0.43 %
#
# strat returns: Date
# 2013-04-10    0.004088
# 2013-04-11    0.001606
# 2013-04-12    0.000353
# 2013-04-15   -0.005126
# 2013-04-16    0.007123
#                 ...
# 2017-12-01    0.011811
# 2017-12-04   -0.000437
# 2017-12-05    0.005537
# 2017-12-06   -0.002431
# 2017-12-07   -0.002629
# Name: strategy_returns, Length: 1177, dtype: float64
# In-Sample Sharpe Ratio: 2.4492409893383558
# Out-of-Sample Sharpe Ratio: 5.9974616238436615
# OS/IS Ratio: 2.4487021285168966
#
# In-Sample IC: 0.013911558907582552
# Out-of-Sample IC: 0.021743159580840186
# /Users/kleonang/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# In-Sample RIC: 0.01749052001853251
# Out-of-Sample RIC: 0.027223840942565046
# In-Sample CAGR: 0.1669074727053288
# Out-of-Sample CAGR: 0.751491089189132
# In-Sample Max Drawdown: 0.0719144103474007
# Out-of-Sample Max Drawdown: 0.026461489604787836
# In-Sample Sortino Ratio: 3.5462271995626606
# Out-of-Sample Sortino Ratio: 11.13082391947693
# In-Sample Calmar Ratio: 10.855833237625378
# Out-of-Sample Calmar Ratio: 26.08544723616726

# %%
# Pure Alpha Strategy (no rank)
simulator = StrategySimulator(sim_start, sim_end, is_start, os_start, delay=0)
simulator.simulate()
# Out:
# Max weight: 93.84 %
#
# strat returns: Date
# 2013-04-10    0.052567
# 2013-04-11    0.051321
# 2013-04-12    0.058965
# 2013-04-15    0.099672
# 2013-04-16    0.052385
#                 ...
# 2017-12-01    2.121073
# 2017-12-04    0.073872
# 2017-12-05    0.043789
# 2017-12-06    0.205493
# 2017-12-07    0.049385
# Name: strategy_returns, Length: 1177, dtype: float64
# In-Sample Sharpe Ratio: 5.9995406444119235
# Out-of-Sample Sharpe Ratio: 9.98983349264185
# OS/IS Ratio: 1.6650997275844035
#
# In-Sample IC: 1.0
# Out-of-Sample IC: 1.0
# In-Sample CAGR: 67358452950.56662
# Out-of-Sample CAGR: 2.1797215952680343e+33
# In-Sample Max Drawdown: -0.0
# Out-of-Sample Max Drawdown: -0.0
# In-Sample Sortino Ratio: nan
# Out-of-Sample Sortino Ratio: nan
# In-Sample Calmar Ratio: -inf
# Out-of-Sample Calmar Ratio: -inf
# /Users/kleonang/Documents/NUS/Y4S1/CP4101/backtester/StrategyStatistics.py:31: RuntimeWarning: divide by zero encountered in double_scalars
#   return (self.returns_series.iloc[-1] / self.returns_series.iloc[0]) ** (252 / len(self.returns_series)) - 1

# %%
# Pure Alpha Strategy (rank)
simulator.simulate()
# Out:
# Max weight: 0.42 %
#
# strat returns: Date
# 2013-04-10    0.037552
# 2013-04-11    0.031201
# 2013-04-12    0.031853
# 2013-04-15    0.049877
# 2013-04-16    0.036986
#                 ...
# 2017-12-01    0.050503
# 2017-12-04    0.051807
# 2017-12-05    0.032139
# 2017-12-06    0.035674
# 2017-12-07    0.032425
# Name: strategy_returns, Length: 1177, dtype: float64
# In-Sample Sharpe Ratio: 76.14801128255313
# Out-of-Sample Sharpe Ratio: 72.6025771933169
# OS/IS Ratio: 0.9534402274002848
#
# In-Sample IC: 0.8687784778320817
# Out-of-Sample IC: 0.8614521794818033
# In-Sample CAGR: 7799.795126107048
# Out-of-Sample CAGR: 10477.9214908723
# In-Sample Max Drawdown: -0.0
# Out-of-Sample Max Drawdown: -0.0
# In-Sample Sortino Ratio: nan
# Out-of-Sample Sortino Ratio: nan
# In-Sample Calmar Ratio: -inf
# Out-of-Sample Calmar Ratio: -inf
# /Users/kleonang/Documents/NUS/Y4S1/CP4101/backtester/StrategyStatistics.py:31: RuntimeWarning: divide by zero encountered in double_scalars
#   return (self.returns_series.iloc[-1] / self.returns_series.iloc[0]) ** (252 / len(self.returns_series)) - 1

# %%
r = pickle.load(open("../data/returns.pickle", 'rb'))
r
# Out:
#                 AABA      AAON      AAPL      AAWW      AAXJ      AAXN  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05  0.007602 -0.028716  0.001963  0.055236  0.011195  0.010753
# 2010-01-06 -0.003482 -0.040000 -0.015997 -0.041677 -0.000865  0.242553
# 2010-01-07 -0.027373  0.038043 -0.001991  0.008284 -0.004848 -0.030822
# 2010-01-08  0.000000  0.012216  0.006649  0.008216  0.004001 -0.017668
# ...              ...       ...       ...       ...       ...       ...
# 2017-12-04 -0.025535  0.030261 -0.007308 -0.015280 -0.001730 -0.015523
# 2017-12-05 -0.002635  0.002670 -0.000942 -0.019828  0.000267 -0.000415
# 2017-12-06  0.018788 -0.033289 -0.003714 -0.006157 -0.015463 -0.003736
# 2017-12-07  0.011670 -0.001377  0.001834  0.015044  0.007447  0.013750
# 2017-12-08  0.014668 -0.015172  0.000295 -0.001744  0.012230  0.007193
#
#                 ABAX      ABCB      ABCO      ABMD  ...      YNDX      YORW  \
# Date                                                ...
# 2010-01-04       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-05  0.000803  0.011080 -0.017990 -0.024027  ...       NaN -0.012760
# 2010-01-06  0.031701  0.020548  0.005685 -0.015240  ...       NaN -0.029932
# 2010-01-07  0.000000  0.032215  0.004397  0.000000  ...       NaN -0.002805
# 2010-01-08 -0.003501  0.003901  0.001876 -0.020238  ...       NaN  0.004219
# ...              ...       ...       ...       ...  ...       ...       ...
# 2017-12-04 -0.013295  0.007035  0.000000 -0.025848  ... -0.015370  0.002786
# 2017-12-05 -0.008421 -0.015968  0.000000 -0.008493  ...  0.010615 -0.030556
# 2017-12-06  0.023992 -0.018256  0.000000 -0.005107  ...  0.007723 -0.001433
# 2017-12-07 -0.023429 -0.016529  0.000000  0.004866  ...  0.012262 -0.005739
# 2017-12-08  0.011465 -0.011555  0.000000  0.018360  ... -0.003937 -0.002886
#
#                 YRCW        YY      ZBRA      ZEUS      ZGNX      ZION  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05 -0.060773       NaN -0.001744 -0.006499       NaN  0.035259
# 2010-01-06  0.191029       NaN -0.007687  0.039251       NaN  0.086957
# 2010-01-07  0.051982       NaN -0.025000 -0.012876       NaN  0.112000
# 2010-01-08 -0.002230       NaN -0.003250  0.031304       NaN -0.016187
# ...              ...       ...       ...       ...       ...       ...
# 2017-12-04  0.044283  0.003872 -0.007702  0.011566 -0.112468  0.033147
# 2017-12-05 -0.004626 -0.004351 -0.019633 -0.020962  0.009413 -0.016622
# 2017-12-06  0.030984  0.002781 -0.019095 -0.018005 -0.021521 -0.018868
# 2017-12-07  0.048084  0.085677  0.022410  0.012389  0.061584  0.011018
# 2017-12-08  0.020789 -0.034303  0.002229  0.013216  0.013812  0.009114
#
#                  ZIV      ZUMZ
# Date
# 2010-01-04       NaN       NaN
# 2010-01-05       NaN -0.005663
# 2010-01-06       NaN  0.031733
# 2010-01-07       NaN  0.156151
# 2010-01-08       NaN  0.004775
# ...              ...       ...
# 2017-12-04  0.018667  0.070175
# 2017-12-05  0.004612 -0.032787
# 2017-12-06 -0.002978  0.019370
# 2017-12-07  0.013441  0.004751
# 2017-12-08  0.012403  0.002364
#
# [1998 rows x 1048 columns]

# %%
# %load_ext tensorboard
# %tensorboard --logdir tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-111dc169403ab4a7" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-111dc169403ab4a7");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
